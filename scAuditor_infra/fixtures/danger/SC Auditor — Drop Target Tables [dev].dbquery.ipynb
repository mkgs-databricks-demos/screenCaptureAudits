-- %%
-- Drop all SC Auditor analytical tables for a clean DDL re-run.
-- Target: hls_fde_dev.dev_matthew_giglia_sc_auditor (dev)
-- Order: children first (FKs reference sessions/systems), then parents.

DECLARE OR REPLACE VARIABLE catalog_use STRING DEFAULT 'hls_fde_dev';
DECLARE OR REPLACE VARIABLE schema_use STRING DEFAULT 'dev_matthew_giglia_sc_auditor';

SET VARIABLE catalog_use = :catalog_use; 
SET VARIABLE schema_use = :schema_use; 

SELECT catalog_use, schema_use;

USE IDENTIFIER(catalog_use || '.' || schema_use);

DROP TABLE IF EXISTS audit_reports;
DROP TABLE IF EXISTS audit_findings;
DROP TABLE IF EXISTS audit_extractions;
DROP TABLE IF EXISTS audit_screenshots;
DROP TABLE IF EXISTS audit_sessions;
DROP TABLE IF EXISTS target_systems;
