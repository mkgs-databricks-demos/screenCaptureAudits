# %%
1+1

# %%
# %skip
scAuditor_agent is a databricks app intended for auditors in regulated industries to be able to use natural language to create workflows for an agent to follow to take screen shots of systems and then use Databricks Document intelligence to extract data from those screen shots and create audit reports.  review this deployment bundle to get an understanding of the project to date.  additionally note that the app has open telemetry enabled for real time data flowing to the dev target's catalog and schema.

# %% [markdown]
# scAuditor_agent is an asset bundle for a Screen Capturing Auditing Application that will allow any auditor to login into an application, navigate to various screens, take screen shots, extract the data from those screens and package them up into an audit report.   take a look at the code base and familiar with the project structure to date.

# %% [markdown]
# this app has open telemetry enabled, review all the tables currently target catalog.schema
